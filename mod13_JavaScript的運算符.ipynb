# %% [markdown]
# # JavaScript 運算符

# %% [raw]
# 運算符 = 用於賦值。</br>
# 運算符 + 用於加值。</br>
# 運算符 = 用於給Javascript 變量賦值。</br>
# 算術運算符 + 用於把值加起來。

# %%
<!DOCTYPE html>
<html>

<head>
    <meta charset="utf-8">
    <title>菜鳥教程</title>
</head>

<body>

    <p>點擊按鈕計算 x 的值.</p>
    <button onclick="myFunction()">點擊這裡</button>
    <p id="demo"></p>
    <script>
        function myFunction(){
            y = 5;
            z = 2;
            x = y + z;
                document.getElementById("demo").innerHTML = x;
        }
    </script>

</body>

</html>

# %% [markdown]
# # JavaScript 算術運算符

# %% [raw]
# 與 / 或值之間的算術運算。 y =5 ，下面的表格解釋了這些算術運算符 :

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset="utf-8">
#     <title>菜鳥教程</title>
# </head>
#
# <body>
#
#     <p>設置 y=5, 計算出 x=++y, 並顯示結果。</p>
#     <button onclick="myFunction()">點我</button>
#     <p id="demo"></p>
#     <script>
#         function myFunction(){
#         var y = 5;
#         var x = ++y;
#         var demoP = documeny.getElementById("demo")
#         demoP.innerHTML = "x=" + x + " ,y=" + y ;
#         }
#     </script>
#     <p><strong>注意:</strong>兩個值 x 和 y 都受到影響。</p>
#
# </body>
#
# </html>

# %% [markdown]
# # JavaScript 賦值運算符

# %% [raw]
# 賦值運算符用於給 JavaScript 變量賦值。 給定 x= 10 和 y = 5，下面的

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# # 用於字符串的 + 運算符

# %% [raw]
# + 運算符用於把文本值或字符串變量加起來（連接起來）。如需把兩個或多個字符串變量連接起來，請使用 + 運算符。

# %%
<!DOCTYPE html>
<html>

<head>
    <meta charset="utf-8">
    <title>菜鳥教程</title>
</head>

<body>

    <p>點擊按鈕創建及增加字符串變量。</p>
    <button onclick="myFunction()">點擊這裏</button>
    <p id="demo"></p>
    <script>
        function myFunction() {
            txt1 = "What a very";
            txt2 = "nice day";
            txt3 = txt1 + txt2;
            document.getElementById("demo").innerHTML = txt3;
        }
    </script>

</body>

</html>

# %% [raw]
# 要想在兩個字符串之間增加空格，需要把空格插入一個字符串之中:

# %%
txt1 = "What a very";
txt2 = "nice day";
txt3 = txt1 + txt2;

# %% [raw]
# 或者把空格插入表達式中:

# %%
txt1 = "What a very";
txt2 = "nice day";
txt3 = txt1 + " " +txt2;

# %% [raw]
# 在以上語句執行後，變量 txt3 包含的值是 : What a very nice day

# %% [markdown]
# # 對字符串和數字進行加法運算

# %% [raw]
# 兩個數字相加，返回數字相加的和，如果數字與字符串相加，返回字符串，如下實例:

# %%
<!DOCTYPE html>
<html>

<head>
    <meta charset="utf-8">
    <title>菜鳥教程</title>
</head>

<body>

    <p>點擊按鈕創建及增加字符串變量。</p>
    <button onclick="myFunction()">點擊這裏</button>
    <p id="demo"></p>
    <script>
        function myFunction(){
            var x = 5 + 5 ;    #10
            var y = "5" + 5 ;  #55
            var z = "Hello" + 5;   #Hello5
            var demoP = document.getElementById("demo");
            demoP.innerHTML = x + "<br>" + y + "<br>" + z;
        }
    </script>

</body>

</html>

# %% [raw]
# 規則 : 如果把數字與字符串相加，結果將成為字符串!
