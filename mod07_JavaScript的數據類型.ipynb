# %% [markdown]
# # JavaScript 數據類型

# %% [raw]
# 值類型(基本類型):字符串(String) 、數字(Number) 、布爾(Boolean) 、空(Null) 、未定義(Undefined) 、Symbol 。
# 引用數據類型(對象類型) : 對象(Object) 、數組(Array)、函數(Function)、還有兩個特殊的對象: 正則(RegExp) 和日期(Date)。

# %% [markdown]
# ![Javascript-DataType.png](attachment:Javascript-DataType.png)

# %% [raw]
# 注意 : Symbol 是 ES6 引入了一種新的原始數據類型，表示獨一無二的值。

# %% [markdown]
# # JavaScript擁有動態類型

# %% [raw]
# JavaScript　擁有動態類型，這意味著相同的變量可用做不同的類型：

# %%
var x;              // x 為 undefined
var x = 5;          // 現在x 為數字
var x = "John";     // 現在x 為字符串

# %%
變量的數據類型可以使用 typeof 操作符來查看:

# %%
<!DOCTYPE html>
<html>

<head>
    <meta charset="utf-8">
    <title>菜鳥教程</title>
</head>

<body>

    <p typeof 操作符返回變量或表達式的類型。></p>
    <p id="demo"></p>
    <script>
        document.getElementById("demo").innerHTML = 
            typeof "john" + "<br>" +                    //string
            typeof 3.14 + "<br>" +                      //number
            typeof false + "<br>" +                     //boolean
            typeof [1, 2, 3, 4] + "<br>" +              //object
            typeof {name : "john" , age : 34} ;         //object
    </script>
    
</body>
</html>

# %% [markdown]
# # JavaScript 字符串

# %% [raw]
# 字符串是存儲字符(比如: "Bill Gate")的變量。
#
# 字符串可以是引號中的任意文本。您可以使用單引號或雙引號:

# %%
var carname="Volvo XC60";
var carname='Volvo XC60';

# %%
您可以在字符串中使用引號，只要不匹配包圍字符串的引號即可:

# %%
<!DOCTYPE html>
<html>

<head>
    <meta charset="utf-8">
    <title>菜鳥教程</title>
</head>

<body>

    <script>
        var carname1 = "Volvo XC60";
        var carname2 = 'Volvo XC60';
        var answer1 = 'It\'s alright' ;               //It's alright
        var answer2 = "He is called \"Johnny\"";      //He is called Johnny
        var answer3 = 'He is called "Johnny"';        //He is called Johnny
        document.write(carname1 + "<br>");
        document.write(carname2 + "<br>");
        document.write(answer1 + "<br>");
        document.write(answer2 + "<br>");
        document.write(answer3 + "<br>");
    </script>
    
</body>
</html>

# %% [raw]
# 您將在本教程的高級部分學到更多關於字符串的知識。

# %% [markdown]
# # JavaScript 數字

# %% [raw]
# JavaScript 只有一種數字類型。數字可以帶小數點，也可以不帶:

# %% [raw]
# var x1=34.00;          //使用小數點來寫
# var x2=34;             //不使用小數點來寫

# %%
極大或極小的數字可以通過科學(指數)計數法來書寫:

# %%
<!DOCTYPE html>
<html>

<head>
    <meta charset="utf-8">
    <title>菜鳥教程</title>
</head>

<body>

    <script>
        var x1 = 34.00;
        var x2 = 34;
        var y = 123e5;
        var x = 123e-5;
        document.write(x1 + "<br>")
        document.write(x2 + "<br>")
        document.write(y + "<br>")
        document.write(z + "<br>")
    </script>
    
</body>
</html>

# %% [markdown]
# # JavaScript 布爾

# %% [raw]
# 布爾(邏輯)只能有兩個值: true 或 false

# %%
var x = true;
var y = false;

# %%
布爾常用在條件測試中。您將在本教程稍後的章節中學到更多關於條件測試的知識。

# %% [markdown]
# # JavaScript 數組

# %% [raw]
# 下面的代碼創建名為 cars 的數組:
#
# var cars = new Array();
# cars[0] = "Saab";
# cars[1] = "Volvo";
# cars[2] = "BMW";
#
# 或者(condensed array):
#
# var cars = new Array("Saab","Volvo","BMW");
#
# 或者(literal array):
#
# var cars=["Saab","Volvo","BMW"];

# %%
<!DOCTYPE html>
<html>

<body>

    <script>
        var i;
        var cars = new Array();
        cars[0] = "Saab";
        cars[1] = "Volvo";
        cars[2] = "BMW";
        
        for(i=0; i < cars.length; i++){
            document.write(cars[i] + "<br>");
        }
    </script>

</body>
</html>

# %%
數組下標是基於零的，所以第一個項目是[0]，第二個是[1]，以此類推。您將在本教程稍後的章節中學到更多關於數組的知識。

# %% [markdown]
# # JavaScript 對象

# %%
對象由括號分隔。在括號內部，對象的屬性以名稱和值對的形式(name : value) 來定義。屬性由逗號分隔 :
    
var person = {firstname: "John" , lastname : "Doe" , id : 5566};
上面例子中的對象(person) 有三個屬性: firstname、lastname 以及 id 。
    
空格和拆行無關緊要。聲明可橫跨多行 : 
    
var person = {
    firstname : "John" ,
    lastname : "Doe" , 
    id : 5566
};

對象屬性有兩種尋址方式:

# %%
name = person.lastname;
name = person['lastname'];

# %%
<!DOCTYPE html>
<html>

<head>
    <meta charset="utf-8">
    <title>菜鳥教程</title>
</head>

<body>

    <script>
        var person = 
        {
            firstname: "John" , 
            lastname: "Doe" , 
            id: 5566
        };
        document.write(person.lastname + "<br>");
        document.write(person["lastname"] + "<br>");
    </script>
    
</body>
</html>

# %%
您將在本教程稍後的章節中學到更多關於對象的知識。

# %% [markdown]
# # Undefined 和 Null

# %%
Undefined 這個值表示變量不含有值。可以通過將變量的值設置為 null 來清空變量。

# %%
cars = null;
person = null;

# %%
<!DOCTYPE html>
<html>

<head>
    <meta charset="utf-8">
    <title>菜鳥教程</title>
</head>

<body>

    <script>
        var person;
        var car = "Volvo";
        document.write("person: " + person + "<br>");
        document.write("car: " + car + "<br>");
        var car = null
        document.write("car: " + car + "<br>");
    </script>
    
</body>
</html>

# %% [markdown]
# # 聲明變量類型

# %%
當您聲明新變量時，可以使用關鍵詞 "new" 來聲明其類型:

# %%
var carname = new String;
var x = new Number;
var y = new Boolean;
var cars = new Array;
var person = new Object;
